# %% [markdown]
# # CarbonRadar SME Demand Evidence Analysis
#
# This notebook uses committed CSV seed data only. It does not scrape websites or call credentialed APIs.

# %%
from carbonradar.demand.load_evidence import load_demand_evidence, validate_evidence_sources
from carbonradar.demand.score_market_signals import score_market_signals, demand_score_frame
from carbonradar.demand.build_demand_report import build_demand_report

# %%
evidence = load_demand_evidence()
validation_report = validate_evidence_sources(evidence)
validation_report

# %%
score = score_market_signals(evidence)
demand_score_frame(score)

# %%
build_demand_report(evidence=evidence)
